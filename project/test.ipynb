# %%
import pandas as pd

print("Hello World")
# Out:
# Hello World

# %%
df = pd.read_csv("../data/cs2_tier1_games.csv",sep=",",encoding="latin1")

df.head()
# Out:
#    Unnamed: 0  match_id  game_id              tournament  team1_id  \
# 0           0   7255854   125823  BLAST Open Spring 2026    288898
# 1           1   7255854   125826  BLAST Open Spring 2026    288898
# 2           2   7255854  -125823  BLAST Open Spring 2026    288898
# 3           3   7230540   125819  BLAST Open Spring 2026    288894
# 4           4   7230540   125821  BLAST Open Spring 2026    288894
#
#            team1  team2_id          team2  score1_match  score2_match  ...  \
# 0  Natus Vincere    288899  Team Vitality             0             3  ...
# 1  Natus Vincere    288899  Team Vitality             0             3  ...
# 2  Natus Vincere    288899  Team Vitality             0             3  ...
# 3     PARIVISION    288895  Natus Vincere             1             2  ...
# 4     PARIVISION    288895  Natus Vincere             1             2  ...
#
#    team2_player4_assists  team2_player4_adr  team2_player4_kast  \
# ...

# %%
df.shape
# Out:
# (9072, 99)
