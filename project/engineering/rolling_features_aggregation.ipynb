# %% [markdown]
# Given previous findings, we find it plausible that the previous models are modeling noise of player position shuffling since player 1-5 is arbitrary and not sorted by skill. Knowing this, to remove the ordering factor, we will collapse the data into aggregative team-level average statistics, but also add standard deviation and range as well to denote the presence of a carry on the team.

# %%
import pandas as pd
df = pd.read_csv("../../data/rolling_feature_engineered_tier_1_games.csv")
df.shape
# Out:
# (5539, 84)

# %%
df.columns
# Out:
# Index(['previous_10_game_team1_player1_average_kills',
#        'previous_10_game_team1_player1_average_deaths',
#        'previous_10_game_team1_player1_average_assists',
#        'previous_10_game_team1_player1_average_adr',
#        'previous_10_game_team1_player1_average_kast',
#        'previous_10_game_team1_player1_average_kddiff',
#        'previous_10_game_team1_player2_average_kills',
#        'previous_10_game_team1_player2_average_deaths',
#        'previous_10_game_team1_player2_average_assists',
#        'previous_10_game_team1_player2_average_adr',
#        'previous_10_game_team1_player2_average_kast',
#        'previous_10_game_team1_player2_average_kddiff',
#        'previous_10_game_team1_player3_average_kills',
#        'previous_10_game_team1_player3_average_deaths',
#        'previous_10_game_team1_player3_average_assists',
#        'previous_10_game_team1_player3_average_adr',
#        'previous_10_game_team1_player3_average_kast',
#        'previous_10_game_team1_player3_average_kddiff',
#        'previous_10_game_team1_player4_average_kills',
#        'previous_10_game_team1_player4_average_deaths',
#        'previous_10_game_team1_player4_average_assists',
#        'previous_10_game_team1_player4_average_adr',
#        'previous_10_game_team1_player4_average_kast',
#        'previous_10_game_team1_player4_average_kddiff',
#        'previous_10_game_team1_player5_average_kills',
#        'previous_10_game_team1_player5_average_deaths',
#        'previous_10_game_team1_player5_average_assists',
#        'previous_10_game_team1_player5_average_adr',
#        'previous_10_game_team1_player5_average_kast',
#        'previous_10_game_team1_player5_average_kddiff',
#        'previous_10_game_team2_player1_average_kills',
#        'previous_10_game_team2_player1_average_deaths',
#        'previous_10_game_team2_player1_average_assists',
#        'previous_10_game_team2_player1_average_adr',
#        'previous_10_game_team2_player1_average_kast',
#        'previous_10_game_team2_player1_average_kddiff',
#        'previous_10_game_team2_player2_average_kills',
#        'previous_10_game_team2_player2_average_deaths',
#        'previous_10_game_team2_player2_average_assists',
#        'previous_10_game_team2_player2_average_adr',
#        'previous_10_game_team2_player2_average_kast',
#        'previous_10_game_team2_player2_average_kddiff',
#        'previous_10_game_team2_player3_average_kills',
#        'previous_10_game_team2_player3_average_deaths',
#        'previous_10_game_team2_player3_average_assists',
#        'previous_10_game_team2_player3_average_adr',
#        'previous_10_game_team2_player3_average_kast',
#        'previous_10_game_team2_player3_average_kddiff',
#        'previous_10_game_team2_player4_average_kills',
#        'previous_10_game_team2_player4_average_deaths',
#        'previous_10_game_team2_player4_average_assists',
#        'previous_10_game_team2_player4_average_adr',
#        'previous_10_game_team2_player4_average_kast',
#        'previous_10_game_team2_player4_average_kddiff',
#        'previous_10_game_team2_player5_average_kills',
#        'previous_10_game_team2_player5_average_deaths',
#        'previous_10_game_team2_player5_average_assists',
#        'previous_10_game_team2_player5_average_adr',
#        'previous_10_game_team2_player5_average_kast',
#        'previous_10_game_team2_player5_average_kddiff', 'team1_win', 'team1',
#        'team2', 'team1_id', 'team2_id', 'game_id', 'match_id', 'tournament',
#        'bestOf', 'map_id', 'map_name', 'datetime',
#        'team1_previous_10_average_map_score',
#        'team2_previous_10_average_map_score', 'team1_player1_id',
#        'team1_player2_id', 'team1_player3_id', 'team1_player4_id',
#        'team1_player5_id', 'team2_player1_id', 'team2_player2_id',
#        'team2_player3_id', 'team2_player4_id', 'team2_player5_id'],
#       dtype='object')

# %%
stats = ["kills", "deaths", "assists", "adr", "kast", "kddiff"]
for i in range(1, 3):
    for stat in stats:
        stat_cols_for_team = [f"previous_10_game_team{i}_player{k}_average_{stat}" for k in range(1, 6)]
        df[f"previous_10_games_team{i}_average_{stat}"] = df[stat_cols_for_team].mean(axis=1)
        df[f"previous_10_games_team{i}_std_{stat}"] = df[stat_cols_for_team].std(ddof=0, axis=1)
        df[f"previous_10_games_team{i}_range_{stat}"] = df[stat_cols_for_team].max(axis=1) - df[stat_cols_for_team].min(axis=1)
        df[f"previous_10_games_team{i}_max_{stat}"] = df[stat_cols_for_team].max(axis=1)
        df[f"previous_10_games_team{i}_min_{stat}"] = df[stat_cols_for_team].min(axis=1)
        df = df.drop(stat_cols_for_team, axis=1)

# %% [markdown]
# Let's examine the new feature set

# %%
df.shape
# Out:
# (5539, 84)

# %%
df.columns
# Out:
# Index(['team1_win', 'team1', 'team2', 'team1_id', 'team2_id', 'game_id',
#        'match_id', 'tournament', 'bestOf', 'map_id', 'map_name', 'datetime',
#        'team1_previous_10_average_map_score',
#        'team2_previous_10_average_map_score', 'team1_player1_id',
#        'team1_player2_id', 'team1_player3_id', 'team1_player4_id',
#        'team1_player5_id', 'team2_player1_id', 'team2_player2_id',
#        'team2_player3_id', 'team2_player4_id', 'team2_player5_id',
#        'previous_10_games_team1_average_kills',
#        'previous_10_games_team1_std_kills',
#        'previous_10_games_team1_range_kills',
#        'previous_10_games_team1_max_kills',
#        'previous_10_games_team1_min_kills',
#        'previous_10_games_team1_average_deaths',
#        'previous_10_games_team1_std_deaths',
#        'previous_10_games_team1_range_deaths',
#        'previous_10_games_team1_max_deaths',
#        'previous_10_games_team1_min_deaths',
#        'previous_10_games_team1_average_assists',
#        'previous_10_games_team1_std_assists',
#        'previous_10_games_team1_range_assists',
#        'previous_10_games_team1_max_assists',
#        'previous_10_games_team1_min_assists',
#        'previous_10_games_team1_average_adr',
#        'previous_10_games_team1_std_adr', 'previous_10_games_team1_range_adr',
#        'previous_10_games_team1_max_adr', 'previous_10_games_team1_min_adr',
#        'previous_10_games_team1_average_kast',
#        'previous_10_games_team1_std_kast',
#        'previous_10_games_team1_range_kast',
#        'previous_10_games_team1_max_kast', 'previous_10_games_team1_min_kast',
#        'previous_10_games_team1_average_kddiff',
#        'previous_10_games_team1_std_kddiff',
#        'previous_10_games_team1_range_kddiff',
#        'previous_10_games_team1_max_kddiff',
#        'previous_10_games_team1_min_kddiff',
#        'previous_10_games_team2_average_kills',
#        'previous_10_games_team2_std_kills',
#        'previous_10_games_team2_range_kills',
#        'previous_10_games_team2_max_kills',
#        'previous_10_games_team2_min_kills',
#        'previous_10_games_team2_average_deaths',
#        'previous_10_games_team2_std_deaths',
#        'previous_10_games_team2_range_deaths',
#        'previous_10_games_team2_max_deaths',
#        'previous_10_games_team2_min_deaths',
#        'previous_10_games_team2_average_assists',
#        'previous_10_games_team2_std_assists',
#        'previous_10_games_team2_range_assists',
#        'previous_10_games_team2_max_assists',
#        'previous_10_games_team2_min_assists',
#        'previous_10_games_team2_average_adr',
#        'previous_10_games_team2_std_adr', 'previous_10_games_team2_range_adr',
#        'previous_10_games_team2_max_adr', 'previous_10_games_team2_min_adr',
#        'previous_10_games_team2_average_kast',
#        'previous_10_games_team2_std_kast',
#        'previous_10_games_team2_range_kast',
#        'previous_10_games_team2_max_kast', 'previous_10_games_team2_min_kast',
#        'previous_10_games_team2_average_kddiff',
#        'previous_10_games_team2_std_kddiff',
#        'previous_10_games_team2_range_kddiff',
#        'previous_10_games_team2_max_kddiff',
#        'previous_10_games_team2_min_kddiff'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#       team1_win        team1         team2  team1_id  team2_id  game_id  \
# 3309          1   Complexity  Getting Info    268284    268285   122633
# 3589          0  NRG Esports  Team Falcons    270072    270073   123153
# 1255          1         MOUZ    Complexity    245527    245528   118356
# 4658          1  The Mongolz        Heroic    280552    280553   124605
# 436           0  GamerLegion          MOUZ    239007    239008   116853
#
#       match_id                                    tournament  bestOf  map_id  \
# 3309   2445013  BLAST.tv Austin Major 2025. Closed Qualifier     3.0    23.0
# 3589   2759437                               IEM Dallas 2025     3.0     3.0
# 1255   1284730                               IEM Dallas 2024     3.0    24.0
# 4658   5166827                              IEM Chengdu 2025     3.0     5.0
# 436     841469                             IEM Katowice 2024     3.0    24.0
#
#       ... previous_10_games_team2_average_kast  \
# 3309  ...                            64.259873
# 3589  ...                            74.006000
# 1255  ...                            70.398000
# 4658  ...                            70.284000
# 436   ...                            69.152000
#
#      previous_10_games_team2_std_kast  previous_10_games_team2_range_kast  \
# 3309                         2.268312                            6.834921
# 3589                         1.907350                            4.980000
# 1255                         2.599034                            5.880000
# 4658                         4.952077                           13.310000
# 436                          2.083827                            6.150000
#
#       previous_10_games_team2_max_kast  previous_10_games_team2_min_kast  \
# 3309                         68.057143                         61.222222
# 3589                         76.010000                         71.030000
# 1255                         73.790000                         67.910000
# 4658                         75.560000                         62.250000
# 436                          72.740000                         66.590000
#
#       previous_10_games_team2_average_kddiff  \
# 3309                               -2.289206
# 3589                                0.280000
# 1255                                0.080000
# 4658                                0.220000
# 436                                -1.300000
#
#       previous_10_games_team2_std_kddiff  \
# 3309                            1.012504
# 3589                            2.825173
# 1255                            1.803774
# 4658                            3.116023
# 436                             1.991984
#
#       previous_10_games_team2_range_kddiff  \
# 3309                              3.031746
# 3589                              8.300000
# 1255                              4.500000
# 4658                              7.600000
# 436                               5.600000
#
#       previous_10_games_team2_max_kddiff  previous_10_games_team2_min_kddiff
# 3309                           -0.857143                           -3.888889
# 3589                            5.500000                           -2.800000
# 1255                            1.900000                           -2.600000
# 4658                            3.100000                           -4.500000
# 436                             1.200000                           -4.400000
#
# [5 rows x 84 columns]

# %% [markdown]
# Let's save the new set

# %%
df.to_csv("../../data/aggregated_rolling_features.csv")
