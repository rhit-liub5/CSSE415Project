# %% [markdown]
# Given previous findings, we find it plausible that the previous models are modeling noise of player position shuffling since player 1-5 is arbitrary and not sorted by skill. Knowing this, to remove the ordering factor, we will collapse the data into aggregative team-level average statistics, but also add standard deviation and range as well to denote the presence of a carry on the team.

# %%
import pandas as pd
df = pd.read_csv("../../data/rolling_feature_engineered_tier_1_games.csv")
df.shape
# Out:
# (5539, 84)

# %%
df.columns
# Out:
# Index(['previous_10_game_team1_player1_average_kills',
#        'previous_10_game_team1_player1_average_deaths',
#        'previous_10_game_team1_player1_average_assists',
#        'previous_10_game_team1_player1_average_adr',
#        'previous_10_game_team1_player1_average_kast',
#        'previous_10_game_team1_player1_average_kddiff',
#        'previous_10_game_team1_player2_average_kills',
#        'previous_10_game_team1_player2_average_deaths',
#        'previous_10_game_team1_player2_average_assists',
#        'previous_10_game_team1_player2_average_adr',
#        'previous_10_game_team1_player2_average_kast',
#        'previous_10_game_team1_player2_average_kddiff',
#        'previous_10_game_team1_player3_average_kills',
#        'previous_10_game_team1_player3_average_deaths',
#        'previous_10_game_team1_player3_average_assists',
#        'previous_10_game_team1_player3_average_adr',
#        'previous_10_game_team1_player3_average_kast',
#        'previous_10_game_team1_player3_average_kddiff',
#        'previous_10_game_team1_player4_average_kills',
#        'previous_10_game_team1_player4_average_deaths',
#        'previous_10_game_team1_player4_average_assists',
#        'previous_10_game_team1_player4_average_adr',
#        'previous_10_game_team1_player4_average_kast',
#        'previous_10_game_team1_player4_average_kddiff',
#        'previous_10_game_team1_player5_average_kills',
#        'previous_10_game_team1_player5_average_deaths',
#        'previous_10_game_team1_player5_average_assists',
#        'previous_10_game_team1_player5_average_adr',
#        'previous_10_game_team1_player5_average_kast',
#        'previous_10_game_team1_player5_average_kddiff',
#        'previous_10_game_team2_player1_average_kills',
#        'previous_10_game_team2_player1_average_deaths',
#        'previous_10_game_team2_player1_average_assists',
#        'previous_10_game_team2_player1_average_adr',
#        'previous_10_game_team2_player1_average_kast',
#        'previous_10_game_team2_player1_average_kddiff',
#        'previous_10_game_team2_player2_average_kills',
#        'previous_10_game_team2_player2_average_deaths',
#        'previous_10_game_team2_player2_average_assists',
#        'previous_10_game_team2_player2_average_adr',
#        'previous_10_game_team2_player2_average_kast',
#        'previous_10_game_team2_player2_average_kddiff',
#        'previous_10_game_team2_player3_average_kills',
#        'previous_10_game_team2_player3_average_deaths',
#        'previous_10_game_team2_player3_average_assists',
#        'previous_10_game_team2_player3_average_adr',
#        'previous_10_game_team2_player3_average_kast',
#        'previous_10_game_team2_player3_average_kddiff',
#        'previous_10_game_team2_player4_average_kills',
#        'previous_10_game_team2_player4_average_deaths',
#        'previous_10_game_team2_player4_average_assists',
#        'previous_10_game_team2_player4_average_adr',
#        'previous_10_game_team2_player4_average_kast',
#        'previous_10_game_team2_player4_average_kddiff',
#        'previous_10_game_team2_player5_average_kills',
#        'previous_10_game_team2_player5_average_deaths',
#        'previous_10_game_team2_player5_average_assists',
#        'previous_10_game_team2_player5_average_adr',
#        'previous_10_game_team2_player5_average_kast',
#        'previous_10_game_team2_player5_average_kddiff', 'team1_win', 'team1',
#        'team2', 'team1_id', 'team2_id', 'game_id', 'match_id', 'tournament',
#        'bestOf', 'map_id', 'map_name', 'datetime',
#        'team1_previous_10_average_map_score',
#        'team2_previous_10_average_map_score', 'team1_player1_id',
#        'team1_player2_id', 'team1_player3_id', 'team1_player4_id',
#        'team1_player5_id', 'team2_player1_id', 'team2_player2_id',
#        'team2_player3_id', 'team2_player4_id', 'team2_player5_id'],
#       dtype='object')

# %%
stats = ["kills", "deaths", "assists", "adr", "kast", "kddiff"]
for i in range(1, 3):
    for stat in stats:
        stat_cols_for_team = [f"previous_10_game_team{i}_player{k}_average_{stat}" for k in range(1, 6)]
        df[f"team{i}_average_{stat}"] = df[stat_cols_for_team].mean(axis=1)
        df[f"team{i}_std_{stat}"] = df[stat_cols_for_team].std(ddof=0, axis=1)
        df[f"team{i}_range_{stat}"] = df[stat_cols_for_team].max(axis=1) - df[stat_cols_for_team].min(axis=1)
        df[f"team{i}_max_{stat}"] = df[stat_cols_for_team].max(axis=1)
        df[f"team{i}_min_{stat}"] = df[stat_cols_for_team].min(axis=1)
        df = df.drop(stat_cols_for_team, axis=1)

# %% [markdown]
# Let's examine the new feature set

# %%
df.shape
# Out:
# (5539, 84)

# %%
df.columns
# Out:
# Index(['team1_win', 'team1', 'team2', 'team1_id', 'team2_id', 'game_id',
#        'match_id', 'tournament', 'bestOf', 'map_id', 'map_name', 'datetime',
#        'team1_previous_10_average_map_score',
#        'team2_previous_10_average_map_score', 'team1_player1_id',
#        'team1_player2_id', 'team1_player3_id', 'team1_player4_id',
#        'team1_player5_id', 'team2_player1_id', 'team2_player2_id',
#        'team2_player3_id', 'team2_player4_id', 'team2_player5_id',
#        'team1_average_kills', 'team1_std_kills', 'team1_range_kills',
#        'team1_max_kills', 'team1_min_kills', 'team1_average_deaths',
#        'team1_std_deaths', 'team1_range_deaths', 'team1_max_deaths',
#        'team1_min_deaths', 'team1_average_assists', 'team1_std_assists',
#        'team1_range_assists', 'team1_max_assists', 'team1_min_assists',
#        'team1_average_adr', 'team1_std_adr', 'team1_range_adr',
#        'team1_max_adr', 'team1_min_adr', 'team1_average_kast',
#        'team1_std_kast', 'team1_range_kast', 'team1_max_kast',
#        'team1_min_kast', 'team1_average_kddiff', 'team1_std_kddiff',
#        'team1_range_kddiff', 'team1_max_kddiff', 'team1_min_kddiff',
#        'team2_average_kills', 'team2_std_kills', 'team2_range_kills',
#        'team2_max_kills', 'team2_min_kills', 'team2_average_deaths',
#        'team2_std_deaths', 'team2_range_deaths', 'team2_max_deaths',
#        'team2_min_deaths', 'team2_average_assists', 'team2_std_assists',
#        'team2_range_assists', 'team2_max_assists', 'team2_min_assists',
#        'team2_average_adr', 'team2_std_adr', 'team2_range_adr',
#        'team2_max_adr', 'team2_min_adr', 'team2_average_kast',
#        'team2_std_kast', 'team2_range_kast', 'team2_max_kast',
#        'team2_min_kast', 'team2_average_kddiff', 'team2_std_kddiff',
#        'team2_range_kddiff', 'team2_max_kddiff', 'team2_min_kddiff'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#       team1_win              team1          team2  team1_id  team2_id  \
# 4398          1       Team Falcons  Natus Vincere    279272    279273
# 961           1               MIBR  FURIA Esports    243531    243532
# 4210          1      Aurora Gaming          TYLOO    277352    277353
# 4853          0  Ninjas in Pyjamas     Team 3DMAX    282474    282475
# 578           1               MIBR    NRG Esports    240403    240404
#
#       game_id  match_id                                   tournament  bestOf  \
# 4398   124310   4695084                     ESL Pro League Season 22     3.0
# 961    117814   1136668      Global Esports Tour Rio de Janeiro 2024     3.0
# 4210   124056   4172625                   FISSURE PLAYGROUND 2 â?CS     3.0
# 4853   124822   5725244               StarLadder Budapest Major 2025     3.0
# 578    117089    932757  PGL CS2 Major Copenhagen 2024: American RMR     3.0
#
#       map_id  ... team2_average_kast team2_std_kast  team2_range_kast  \
# 4398     2.0  ...             76.526       1.165137             3.670
# 961      5.0  ...             69.599       2.297012             6.020
# 4210     8.0  ...             73.180       2.908965             8.520
# 4853     3.0  ...             69.630       3.236622             8.740
# 578      5.0  ...             66.915       5.989795            14.675
#
#       team2_max_kast  team2_min_kast  team2_average_kddiff  team2_std_kddiff  \
# 4398           78.41          74.740                  1.46          2.279123
# 961            72.83          66.810                 -1.08          1.778089
# 4210           76.43          67.910                 -0.40          2.209072
# 4853           73.37          64.630                 -0.64          1.243543
# 578            75.30          60.625                 -2.65          2.462722
#
#       team2_range_kddiff  team2_max_kddiff  team2_min_kddiff
# 4398                6.20               4.1             -2.10
# 961                 5.60               1.6             -4.00
# 4210                6.40               2.8             -3.60
# 4853                3.30               1.2             -2.10
# 578                 6.25               0.5             -5.75
#
# [5 rows x 84 columns]

# %% [markdown]
# Let's save the new set

# %%
df.to_csv("../../data/aggregated_rolling_features.csv")
