# %% [markdown]
# # We begin with classification, so we fit a baseline classifier that predicts the mode

# %%
import pandas as pd
cleaned_data = "../../data/cleaned_cs2_games_pregame.csv"
df = pd.read_csv(cleaned_data, encoding="latin1")
df
# Out:
#       tournament  team1_id  team1  team2_id  team2  bestOf  map_name  \
# 0             10    288898    122    288899    199     5.0         3
# 1             10    288898    122    288899    199     5.0         1
# 2             10    288894    137    288895    128     3.0         3
# 3             10    288894    137    288895    128     3.0         4
# 4             10    288894    137    288895    128     3.0         2
# ...          ...       ...    ...       ...    ...     ...       ...
# 5564         110    233631    117    233632    215     3.0         1
# 5565         110    233631    117    233632    215     3.0         6
# 5566         110    233621     42    233622     68     3.0         6
# 5567         110    233621     42    233622     68     3.0         3
# 5568         110    233621     42    233622     68     3.0         0
#
#       team1_win  team1_player1_id  team1_player2_id  ...  team1_player5_id  \
# ...

# %% [markdown]
# # Baseline accuracy rate

# %%
mode = df.team1_win.mode()[0]
err_rate = len(df[df.team1_win == mode])/len(df)
# Out:
# 0.5469563655952595

# %% [markdown]
# So the mode is right 55% of the time.
